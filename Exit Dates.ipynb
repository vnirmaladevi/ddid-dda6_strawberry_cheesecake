# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ddid = pd.read_csv(r'C:\Users\olie_\Documents\nss-data-analytics\Python\Projects\ddid-dda6_strawberry_cheesecake\data\No_Blanks_ISFP.csv')

# %%
ddid.head()
# Out:
#   POE  Child ID         DOB Notification Date Initial Eligibility Date  \
# 0  UC    429480   1/12/2018         1/23/2018                1/31/2018
# 1  NW    423741    9/4/2017          9/6/2017                9/21/2017
# 2  UC    427513  11/21/2017         12/6/2017               12/15/2017
# 3  ET    430611    2/1/2018         2/13/2018                2/27/2018
# 4  NW    426439  10/29/2017         11/6/2017               11/16/2017
#
#   Initial IFSP Date Latest IFSP Date  \
# 0         1/31/2018        9/21/2020
# 1         9/26/2017        7/21/2020
# 2        12/21/2017        8/26/2020
# 3          3/1/2018        9/11/2020
# 4        11/29/2017        9/30/2020
#
#                                          Exit Reason   Exit Date  \
# 0                              618 - Part B eligible   1/11/2021
# 1  618 - Not eligible for Part B – Exit with refe...    9/3/2020
# 2            618 - Part B eligibility not determined  11/20/2020
# ...

# %%
exit_notes = ddid[ddid['Exit Note'].notna()]

# %%
exit_notes.head()
# Out:
#    POE  Child ID         DOB Notification Date Initial Eligibility Date  \
# 1   NW    423741    9/4/2017          9/6/2017                9/21/2017
# 2   UC    427513  11/21/2017         12/6/2017               12/15/2017
# 3   ET    430611    2/1/2018         2/13/2018                2/27/2018
# 9   SE    423973    9/7/2017         9/12/2017               10/11/2017
# 10  ET    424229    9/6/2017         9/15/2017               10/18/2017
#
#    Initial IFSP Date Latest IFSP Date  \
# 1          9/26/2017        7/21/2020
# 2         12/21/2017        8/26/2020
# 3           3/1/2018        9/11/2020
# 9         10/17/2017         5/7/2020
# 10        10/18/2017        3/16/2020
#
#                                           Exit Reason   Exit Date  \
# 1   618 - Not eligible for Part B – Exit with refe...    9/3/2020
# 2             618 - Part B eligibility not determined  11/20/2020
# 3                               618 - Part B eligible   1/29/2021
# ...

# %%
exit_notes=exit_notes[exit_notes['Exit Note'].str.contains('Reopened','Re-Opened')]

# %%
exit_notes
# Out:
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 1     NW    423741   9/4/2017          9/6/2017                9/21/2017
# 3     ET    430611   2/1/2018         2/13/2018                2/27/2018
# 9     SE    423973   9/7/2017         9/12/2017               10/11/2017
# 10    ET    424229   9/6/2017         9/15/2017               10/18/2017
# 11    MD    422058  7/21/2017          8/1/2017                8/24/2017
# ...   ..       ...        ...               ...                      ...
# 5570  SC    480223  9/12/2018         4/23/2020                 5/1/2020
# 5571  ET    487833  9/19/2019         11/3/2020               11/13/2020
# 5572  ET    487832  9/19/2019         11/3/2020               11/13/2020
# 5573  SC    465241  7/20/2017        12/10/2019                1/13/2020
# 5574  SC    468796  7/27/2019        12/11/2019                1/15/2020
#
#      Initial IFSP Date Latest IFSP Date  \
# 1            9/26/2017        7/21/2020
# ...
